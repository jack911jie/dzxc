# %%
import requests
import datetime
import json

class qywxrobot:
    def __init__(self):
        
        self.api='https://qyapi.weixin.qq.com/cgi-bin/webhook/send?key=ba5e3739-8c78-4e37-bf2e-6747cd5ab1cb'
        #配置请求的header
        self.headers={'Content-Type':'text/plain',}
        
        #可以自定义相关方法自动获取相关数据
        getEnvInfoSign='性能测试环境'
        getEnvInfo='Dubbo-PO'
        getEnvInfo2='模块有版本更新!'
        getEnvInfoVersion='V1.0.1'
        getWarning='请注意确认是否影响当前测试!'
        getUpdateTime = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        getUpdateName='阿晓老师'
    
    def sending(self):
        data=self.pic()
        requests.post(url=self.api,headers=self.headers,json=data)
        print('已发送')
        
    def markdown(self):
        #定义markdown类型
        dataMarkdown={"msgtype": "markdown",
                        "markdown":{"content":
                             "怎么样改变自己的思维方式？\n"+
                        "<font color=\"warning\">"+
                             "未来的孩子需要什么样的能力？\n" +
                        "</font>"+
                        "<font color=\"info\"> "+
                             "大智小超科学实验室\n" +
                        "</font>"+"\n"+        
                             "[点击观看视频](https://mp.weixin.qq.com/s/6tKdXa44lyZwPkga9dG26g)"
                        }
                    }

        return dataMarkdown
    
    def pic(self):
        pic={
                "msgtype": "news",
                "news": {
                   "articles" : [
                       {
                           "title" : "马云爸爸教你怎么教育孩子",
                           "description" : "未来的孩子需要什么样的能力？",
                           "url" : "https://mp.weixin.qq.com/s/6tKdXa44lyZwPkga9dG26g",
                           "picurl" : "https://chuntianhuahua-1257410889.cos.ap-guangzhou.myqcloud.com/mimoPic/hdg-main-01.png"
                       }
                    ]
                }
            }
        return pic
    def txt(self):
        #定义文本类型
        dataText={   "msgtype": "text",
                "text":{        
                "content": "我是企业微信机器人，正在发送消息。\n阿晓老师",
#                 "mentioned_mobile_list"
#                 :[
#                 "@all"
#                 ]   
                }

            }
        return dataText
        
        
if __name__=='__main__':
    myrobot=qywxrobot()
    myrobot.sending()
# Out:
# 已发送

# %%
import  requests

import
 datetime



#将
webhook
接口赋值给
Robot_XiaoFei

Robot_XiaoFei
=
"https://qyapi.weixin.qq.com/cgi-bin/webhook/send?key=4616537e-b57f-47e5-9497-fb7db9714611"
 
#小飞飞



#配置请求的
header

headers
={
 
'Content-Type'
:
 
'text/plain'
,}



#可以自定义相关方法自动获取相关数据

getEnvInfoSign
=
'性能测试环境'

getEnvInfo
=
'Dubbo-PO'

getEnvInfo2
=
'模块有版本更新!'

getEnvInfoVersion
=
'V1.0.1'

getWarning
=
'请注意确认是否影响当前测试!'

getUpdateTime 
=
 datetime
.
datetime
.
now
().
strftime
(
'%Y-%m-%d %H:%M:%S'
)

getUpdateName
=
'大飞'



#
markdown
类型

dataMarkdown
={

    
"msgtype"
:
 
"markdown"
,

    
"markdown"
:
 
{

        
"content"
:
 getEnvInfoSign 
+
 
"<font color=\"warning\">"
 
+
 getEnvInfo  
+
 
"</font>"
 
+
getEnvInfo2 
+
"\n >"

        
"版本号是:<font color=\"info\"> "
 
+
 getEnvInfoVersion 
+
 
"</font> \n >"

        
"更新时间是:<font color=\"info\">"
 
+
 getUpdateTime 
+
 
"</font>\n"

        
"更新人是：<font color=\"info\">"
 
+
 getUpdateName 
+
 
"</font>\n"

        
"[详情请点击这里](http://work.weixin.qq.com/api/doc) \n"

    
}

}



#主逻辑

requests
.
post
(
url
=
Robot_XiaoFei
,
headers
=
headers
,
json
=
dataMarkdown
)
# Out:
#   File "<ipython-input-43-058c73f7c9fe>", line 1
#     import
#           ^
# SyntaxError: invalid syntax
